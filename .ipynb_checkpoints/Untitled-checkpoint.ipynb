# %%
from matplotlib import pyplot as plt
import pandas as pd
import importlib
import numpy as np

# %%
host_main_branch_fname = "/scratch/05097/hk9457/FIREII/m12c_r7100/tree_processed_data/host_main_branch.csv"
infalling_subtree_fname = "/scratch/05097/hk9457/FIREII/m12c_r7100/bloodhound_subhalo_tracking/infalling_subhalo_result/m12c_r7100_subtree_infall_subhalo.hdf5"
infalling_tree_fname = "/scratch/05097/hk9457/FIREII/m12c_r7100/bloodhound_subhalo_tracking/infalling_subhalo_result/m12c_r7100_tree_infall_subhalo.hdf5"

# %%
host_main_branch_df = pd.read_csv(host_main_branch_fname)
infalling_subtree_df = pd.read_hdf(infalling_subtree_fname)
infalling_tree_df = pd.read_hdf(infalling_tree_fname)
merged_df = pd.concat([infalling_subtree_df, infalling_tree_df])
infalling_only_df = merged_df.query("`infalling?`==1")

# %%
print(len(infalling_subtree_df), len(infalling_tree_df), len(merged_df))
# Out:
# 142924 225902 368826

# %%
infalling_subtree_df[:3]
# Out:
#         tree.tid     scale       dist  am.phantom  am.progenitor.main  \
# 905271   6877074  0.157143  66.534702           0                   1
# 904597   6877074  0.158730  66.651011           0                   1
# 903907   6877074  0.160318  67.027205           0                   1
#
#         axis.b_div.by_a  axis.c_div.by_a  catalog.index  central.index  \
# 905271          0.37283          0.29706           3606      -48624385
# 904597          0.58418          0.33908           3731      -48624385
# 903907          0.60056          0.34296           3864      -48624385
#
#         central.local.index  ...     tid  vel.circ.max  vel.std          vx  \
# 905271            -48624385  ...  612708          6.06     6.12 -167.820007
# 904597            -48624385  ...  640100          5.87     5.91 -169.389999
# 903907            -48624385  ...  668249          5.75     5.91 -170.559998
#
#                 vy          vz  velocity.offset  scale.infall  \
# 905271  204.330002  108.309998             1.03          0.25
# 904597  205.710007  108.750000             1.15          0.25
# 903907  207.240005  108.970001             1.02          0.25
#
#         snapshot.infall  infalling?
# 905271              120           1
# 904597              120           1
# 903907              120           1
#
# [3 rows x 58 columns]

# %%
infalling_tree_df[:3]
# Out:
#           tree.tid     scale        dist  am.phantom  am.progenitor.main  \
# 33408993  64695629  0.126623  122.673001           0                   1
# 33408991  64695629  0.128247  123.293482           0                   1
# 33408989  64695629  0.129870  124.303096           0                   1
#
#           axis.b_div.by_a  axis.c_div.by_a  catalog.index  central.index  \
# 33408993          0.25586          0.15111           1186      -48624385
# 33408991          0.62681          0.53395           1164      -48624385
# 33408989          0.60648          0.50437           1271      -48624385
#
#           central.local.index  ...     tid  vel.circ.max  vel.std          vx  \
# 33408993            -48624385  ...  227931          8.64    10.63 -103.099998
# 33408991            -48624385  ...  242534          8.00    11.37 -101.250000
# 33408989            -48624385  ...  257731          8.80    13.44 -102.889999
#
#                   vy          vz  velocity.offset  scale.infall  \
# 33408993  201.440002  159.149994             2.50      0.251603
# 33408991  208.320007  158.350006             1.57      0.251603
# 33408989  209.279999  158.399994             1.16      0.251603
#
#           snapshot.infall  infalling?
# 33408993              121           1
# 33408991              121           1
# 33408989              121           1
#
# [3 rows x 58 columns]

# %%
merged_df[:3]
# Out:
#         tree.tid     scale       dist  am.phantom  am.progenitor.main  \
# 905271   6877074  0.157143  66.534702           0                   1
# 904597   6877074  0.158730  66.651011           0                   1
# 903907   6877074  0.160318  67.027205           0                   1
#
#         axis.b_div.by_a  axis.c_div.by_a  catalog.index  central.index  \
# 905271          0.37283          0.29706           3606      -48624385
# 904597          0.58418          0.33908           3731      -48624385
# 903907          0.60056          0.34296           3864      -48624385
#
#         central.local.index  ...     tid  vel.circ.max  vel.std          vx  \
# 905271            -48624385  ...  612708          6.06     6.12 -167.820007
# 904597            -48624385  ...  640100          5.87     5.91 -169.389999
# 903907            -48624385  ...  668249          5.75     5.91 -170.559998
#
#                 vy          vz  velocity.offset  scale.infall  \
# 905271  204.330002  108.309998             1.03          0.25
# 904597  205.710007  108.750000             1.15          0.25
# 903907  207.240005  108.970001             1.02          0.25
#
#         snapshot.infall  infalling?
# 905271              120           1
# 904597              120           1
# 903907              120           1
#
# [3 rows x 58 columns]

# %%
merged_df[142923:142928]
# Out:
#           tree.tid     scale        dist  am.phantom  am.progenitor.main  \
# 314       63925358  0.998885  178.760120           0                   0
# 33408993  64695629  0.126623  122.673001           0                   1
# 33408991  64695629  0.128247  123.293482           0                   1
# 33408989  64695629  0.129870  124.303096           0                   1
# 33408987  64695629  0.131494  125.539656           0                   1
#
#           axis.b_div.by_a  axis.c_div.by_a  catalog.index  central.index  \
# 314               0.64045          0.51762          31506            313
# 33408993          0.25586          0.15111           1186      -48624385
# 33408991          0.62681          0.53395           1164      -48624385
# 33408989          0.60648          0.50437           1271      -48624385
# 33408987          0.35186          0.28630           1293      -48624385
#
#           central.local.index  ...       tid  vel.circ.max  vel.std  \
# 314                       313  ...  63925358          2.38     4.23
# 33408993            -48624385  ...    227931          8.64    10.63
# 33408991            -48624385  ...    242534          8.00    11.37
# 33408989            -48624385  ...    257731          8.80    13.44
# 33408987            -48624385  ...    273557          9.67    12.64
#
#                   vx          vy          vz  velocity.offset  scale.infall  \
# 314      -212.600006  264.399994  232.520004             4.40      0.931529
# 33408993 -103.099998  201.440002  159.149994             2.50      0.251603
# 33408991 -101.250000  208.320007  158.350006             1.57      0.251603
# 33408989 -102.889999  209.279999  158.399994             1.16      0.251603
# 33408987 -102.610001  212.149994  158.070007             3.99      0.251603
#
#           snapshot.infall  infalling?
# 314                   548           0
# 33408993              121           1
# 33408991              121           1
# 33408989              121           1
# 33408987              121           1
#
# [5 rows x 58 columns]

# %%
infalling_subtree_df.keys()
# Out:
# Index(['tree.tid', 'scale', 'dist', 'am.phantom', 'am.progenitor.main',
#        'axis.b_div.by_a', 'axis.c_div.by_a', 'catalog.index', 'central.index',
#        'central.local.index', 'descendant.index', 'descendant.snapshot',
#        'dindex', 'final.index', 'host.x', 'host.y', 'host.z', 'host.index',
#        'host.vx', 'host.vy', 'host.vz', 'host.velocity.rad',
#        'host.velocity.tan', 'major.merger.snapshot', 'mass', 'mass.180m',
#        'mass.200c', 'mass.200m', 'mass.500c', 'mass.bound', 'mass.lowres',
#        'mass.vir', 'x', 'y', 'z', 'position.offset', 'progenitor.co.dindex',
#        'progenitor.co.index', 'progenitor.last.dindex',
#        'progenitor.main.index', 'progenitor.main.last.dindex',
#        'progenitor.number', 'radius', 'scale.radius', 'scale.radius.klypin',
#        'snapshot', 'spin.bullock', 'spin.peebles', 'tid', 'vel.circ.max',
#        'vel.std', 'vx', 'vy', 'vz', 'velocity.offset', 'scale.infall',
#        'snapshot.infall', 'infalling?'],
#       dtype='object')

# %%
infall_tids = np.unique(merged_df['tree.tid'].values)
infall_grouped_by_tid = merged_df.groupby(by='tree.tid')
infalling_only_tids = np.unique(infalling_only_df['tree.tid'].values)
infalling_only_grouped_by_tid = infalling_only_df.groupby(by='tree.tid')

# %%
fig, ax = plt.subplots(figsize=(6, 6))
ax.plot(host_main_branch_df['snapshot'].values,
        host_main_branch_df['radius'].values)
for i in range(len(infall_tids)):
    tid = infall_tids[i]
    tree = infall_grouped_by_tid.get_group(tid)
    infall_snap = tree['snapshot.infall'].values[0]
    infall_idx = np.where(tree['snapshot'].values == infall_snap)[0][0]
    infall_row = tree.iloc[infall_idx]
    ax.plot(infall_row['snapshot'], infall_row['dist'], 'o', c='red', rasterized=True, alpha=0.7)
for i in range(len(infalling_only_tids)):
    tid = infalling_only_tids[i]
    tree = infalling_only_grouped_by_tid.get_group(tid)
    infall_snap = tree['snapshot.infall'].values[0]
    infall_idx = np.where(tree['snapshot'].values == infall_snap)[0][0]
    infall_row = tree.iloc[infall_idx]
    ax.plot(infall_row['snapshot'], infall_row['dist'], 'o', c='black', rasterized=True, alpha=0.7)
ax.set(yscale='log')
# Out:
# [None]

# %%
infall_grouped_by_tid.get_group(infall_subtree_tids[0])
# Out:
#         tree.tid     scale        dist  am.phantom  am.progenitor.main  \
# 874581   3986955  0.209375  102.983506           0                   1
# 873305   3986955  0.210938  101.722522           0                   1
# 872013   3986955  0.212500   99.776732           0                   1
# 870698   3986955  0.214062   98.916430           0                   1
# 869348   3986955  0.215625   96.881082           0                   1
# 867983   3986955  0.217188   94.892500           0                   1
# 866591   3986955  0.218750   93.280129           0                   1
# 865178   3986955  0.220312   91.655581           0                   1
# 863736   3986955  0.221875   89.807437           0                   1
# 862265   3986955  0.223438   87.910131           0                   1
# 860777   3986955  0.225000   85.906420           0                   1
# 859272   3986955  0.226562   84.203490           2                   1
# 857737   3986955  0.228125   82.562941           1                   1
# 856178   3986955  0.229687   80.958063           0                   1
# 854600   3986955  0.231250   78.603199           0                   1
# 852992   3986955  0.232813   76.452002           0                   1
# 851364   3986955  0.234375   74.334016           0                   1
# 849716   3986955  0.235937   71.827647           0                   1
# 848034   3986955  0.237500   69.302585           0                   1
# 846323   3986955  0.239063   66.848025           0                   1
# 844587   3986955  0.240625   64.525426           0                   1
# 842825   3986955  0.242188   61.686100           0                   1
# 841047   3986955  0.243750   59.203729           2                   1
# 839243   3986955  0.245312   56.381086           1                   1
# 837427   3986955  0.246875   53.375962           0                   1
# 835594   3986955  0.248438   50.115420           0                   1
# 833743   3986955  0.250000   46.777699           0                   1
# 831879   3986955  0.251603   43.697551           0                   1
# 829996   3986955  0.253205   40.568614           0                   1
# 828082   3986955  0.254808   37.896765           1                   1
# 826147   3986955  0.256410   34.966251           0                   0
#
#         axis.b_div.by_a  axis.c_div.by_a  catalog.index  central.index  \
# 874581         0.787430         0.411000           8394      -48624385
# 873305         0.816980         0.396490           8603      -48624385
# 872013         0.524470         0.287970           8841      -48624385
# 870698         0.792560         0.557200           9001      -48624385
# 869348         0.805330         0.712200           9177      -48624385
# 867983         0.814010         0.771520           9434         867981
# 866591         0.741860         0.701290           9671      -48624385
# 865178         0.826650         0.754720           9798      -48624385
# 863736         0.885360         0.659660          10046      -48624385
# 862265         0.924220         0.705140          10320      -48624385
# 860777         0.729970         0.313230          10447         860776
# 859272         0.670910         0.314423      -48624385      -48624385
# 857737         0.611850         0.315617      -48624385      -48624385
# 856178         0.552790         0.316810          12750      -48624385
# 854600         0.530860         0.325960          12869      -48624385
# 852992         0.623480         0.425080          13187      -48624385
# 851364         0.667230         0.511880          13327      -48624385
# 849716         0.972080         0.774560          13632      -48624385
# 848034         0.961230         0.654190          13867      -48624385
# 846323         0.835650         0.671090          14092      -48624385
# 844587         0.901560         0.715490          12335      -48624385
# 842825         0.737590         0.646760          14381      -48624385
# 841047         0.726167         0.643600      -48624385      -48624385
# 839243         0.714743         0.640440      -48624385         839240
# 837427         0.703320         0.637280          15184         837425
# 835594         0.853750         0.572280          15282         835592
# 833743         0.953150         0.864290          13515         833741
# 831879         0.959080         0.795100          13671         831877
# 829996         0.863350         0.731980          13946         829367
# 828082         0.828585         0.669405      -48624385         827456
# 826147         0.793820         0.606830          14348         825515
#
#         central.local.index  ...      tid  vel.circ.max  vel.std          vx  \
# 874581            -48624385  ...  1938026          6.88    10.07 -159.539993
# 873305            -48624385  ...  1992425          7.08    10.05 -160.389999
# 872013            -48624385  ...  2047674          7.30    10.31 -161.839996
# 870698            -48624385  ...  2103684          7.25    10.28 -163.110001
# 869348            -48624385  ...  2160921          7.43    10.25 -164.729996
# 867983               867981  ...  2219068          7.46    10.13 -165.360001
# 866591            -48624385  ...  2278008          7.50    10.40 -166.860001
# 865178            -48624385  ...  2337878          7.48    10.49 -168.970001
# 863736            -48624385  ...  2398545          6.99    10.71 -171.600006
# 862265            -48624385  ...  2460126          7.42    10.43 -172.169998
# 860777               860776  ...  2522594          6.99    10.66 -175.919998
# 859272            -48624385  ...  2586011          6.99    10.65 -180.270004
# 857737            -48624385  ...  2650432          7.00    10.64 -179.729996
# 856178            -48624385  ...  2715839          7.00    10.63 -179.199997
# 854600            -48624385  ...  2782226          7.14    10.28 -181.740005
# 852992            -48624385  ...  2849544          7.20    10.03 -183.910004
# 851364            -48624385  ...  2917923          7.34    10.28 -185.389999
# 849716            -48624385  ...  2987403          7.57    10.68 -187.039993
# 848034            -48624385  ...  3058065          7.51    10.33 -189.029999
# 846323            -48624385  ...  3129874          7.34    10.72 -191.389999
# 844587            -48624385  ...  3202967          7.51    10.86 -193.449997
# 842825            -48624385  ...  3276545          7.46    11.46 -195.029999
# 841047            -48624385  ...  3351185          7.23    11.26 -208.929993
# 839243               839240  ...  3426980          6.98    11.05 -208.309998
# 837427               837425  ...  3504021          6.72    10.84 -207.690002
# 835594               835592  ...  3582236          6.48    10.61 -211.130005
# 833743               833741  ...  3661115          6.72    11.15 -211.169998
# 831879               831877  ...  3741014          6.83    10.46 -214.889999
# 829996               829994  ...  3822186          6.83    11.39 -219.300003
# 828082               828081  ...  3903964          6.56    14.78 -232.509995
# 826147               826146  ...  3986955          6.27    17.08 -237.029999
#
#                 vy          vz  velocity.offset  scale.infall  \
# 874581  237.589996  220.139999          7.52000      0.251603
# 873305  239.479996  221.830002          7.41000      0.251603
# 872013  241.389999  223.050003          7.60000      0.251603
# 870698  243.309998  224.690002          7.77000      0.251603
# 869348  245.190002  226.470001          7.52000      0.251603
# 867983  247.610001  228.320007          7.48000      0.251603
# 866591  250.020004  229.820007          7.71000      0.251603
# 865178  252.500000  231.800003          8.10000      0.251603
# 863736  254.919998  230.509995          7.66000      0.251603
# 862265  257.739990  234.600006          7.94000      0.251603
# 860777  258.269989  230.550003          6.08000      0.251603
# 859272  267.869995  239.020004          6.21667      0.251603
# 857737  267.070007  238.320007          6.35333      0.251603
# 856178  266.279999  237.610001          6.49000      0.251603
# 854600  267.529999  237.860001          4.89000      0.251603
# 852992  270.230011  238.779999          4.66000      0.251603
# 851364  273.250000  240.360001          4.97000      0.251603
# 849716  275.670013  242.080002          4.84000      0.251603
# 848034  278.410004  243.800003          4.44000      0.251603
# 846323  280.670013  245.410004          4.72000      0.251603
# 844587  285.570007  249.009995          6.32000      0.251603
# 842825  287.350006  250.479996          5.40000      0.251603
# 841047  299.119995  257.820007          6.41000      0.251603
# 839243  298.230011  257.049988          7.42000      0.251603
# 837427  297.350006  256.290009          8.43000      0.251603
# 835594  299.739990  259.149994          8.03000      0.251603
# 833743  310.410004  265.000000          9.67000      0.251603
# 831879  314.649994  268.019989          8.57000      0.251603
# 829996  318.700012  271.209991          9.21000      0.251603
# 828082  322.559998  274.609985         12.33500      0.251603
# 826147  324.540009  274.730011         15.46000      0.251603
#
#         snapshot.infall  infalling?
# 874581              121           1
# 873305              121           1
# 872013              121           1
# 870698              121           1
# 869348              121           1
# 867983              121           1
# 866591              121           1
# 865178              121           1
# 863736              121           1
# 862265              121           1
# 860777              121           1
# 859272              121           1
# 857737              121           1
# 856178              121           1
# 854600              121           1
# 852992              121           1
# 851364              121           1
# 849716              121           1
# 848034              121           1
# 846323              121           1
# 844587              121           1
# 842825              121           1
# 841047              121           1
# 839243              121           1
# 837427              121           1
# 835594              121           1
# 833743              121           1
# 831879              121           1
# 829996              121           1
# 828082              121           1
# 826147              121           1
#
# [31 rows x 58 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 5))
ax.plot(grouped_by_hid.get_group(1097)['scale'].values, grouped_by_hid.get_group(1097)['dist'].values)
